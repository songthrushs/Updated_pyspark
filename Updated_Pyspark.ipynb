# %%
import pandas as pd
import numpy as np

from pyspark.sql import SparkSession, SQLContext

from pyspark.sql.functions import col

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml import Pipeline 
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

from pyspark.ml.regression import LinearRegression
from pyspark.ml.regression import RandomForestRegressor

from pyspark.ml.evaluation import RegressionEvaluator

# %%
# initiating spark

spark = SparkSession.builder.master("local").appName('A2_Spark').getOrCreate()
sc = spark.sparkContext

sqlContext = SQLContext(spark.sparkContext)
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/aalkan/anaconda3/lib/python3.8/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.0.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 21/12/10 10:23:50 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# /home/aalkan/anaconda3/lib/python3.8/site-packages/pyspark/sql/context.py:77: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %%
df = spark.read.csv('white_wine_corr.csv', inferSchema=True, header=True)
df = df.drop('_c0')

X = df.drop('quality')
y = df.select(col('quality'))

# %%
X_Pandas = X.toPandas()
y_Pandas = y.toPandas()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_Pandas, y_Pandas, test_size=0.2, random_state=0)

# %%
ss = {3: 10000, 4: 10000, 5: 10000, 6: 10000, 7: 10000, 8: 10000, 5: 10000}
sm = SMOTE(sampling_strategy=ss, random_state=12, k_neighbors=4)
X_train, y_train = sm.fit_resample(X_train, y_train)
# Out:
# /home/aalkan/.local/lib/python3.8/site-packages/imblearn/utils/_validation.py:299: UserWarning: After over-sampling, the number of samples (10000) in class 3 will be larger than the number of samples in the majority class (class #6.0 -> 1789)
#   warnings.warn(
# /home/aalkan/.local/lib/python3.8/site-packages/imblearn/utils/_validation.py:299: UserWarning: After over-sampling, the number of samples (10000) in class 4 will be larger than the number of samples in the majority class (class #6.0 -> 1789)
#   warnings.warn(
# /home/aalkan/.local/lib/python3.8/site-packages/imblearn/utils/_validation.py:299: UserWarning: After over-sampling, the number of samples (10000) in class 5 will be larger than the number of samples in the majority class (class #6.0 -> 1789)
#   warnings.warn(
# /home/aalkan/.local/lib/python3.8/site-packages/imblearn/utils/_validation.py:299: UserWarning: After over-sampling, the number of samples (10000) in class 6 will be larger than the number of samples in the majority class (class #6.0 -> 1789)
#   warnings.warn(
# /home/aalkan/.local/lib/python3.8/site-packages/imblearn/utils/_validation.py:299: UserWarning: After over-sampling, the number of samples (10000) in class 7 will be larger than the number of samples in the majority class (class #6.0 -> 1789)
#   warnings.warn(
# /home/aalkan/.local/lib/python3.8/site-packages/imblearn/utils/_validation.py:299: UserWarning: After over-sampling, the number of samples (10000) in class 8 will be larger than the number of samples in the majority class (class #6.0 -> 1789)
#   warnings.warn(

# %%
df_1 = pd.DataFrame(X_train, columns=['fixed_acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides',
                                      'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates',
                                      'alcohol'])
df_2 = pd.DataFrame(y_train, columns=['quality'])

# %%
df_new = df_1.combine_first(df_2)
df_new = spark.createDataFrame(df_new)

# %%
print('Total number of rows increased to :  ', df_new.count())
# Out:
# 21/12/10 10:23:58 WARN TaskSetManager: Stage 4 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# Total number of rows increased to :   60005

# %%
assembler = VectorAssembler(inputCols=['fixed_acidity', 'volatile acidity', 'citric acid', 'residual sugar',
                                       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH',
                                       'sulphates', 'alcohol'], outputCol='features')

df_output = assembler.transform(df_new)

# %%
standardScaler = StandardScaler(inputCol="features", outputCol="features_scaled")
scaled_df = standardScaler.fit(df_output).transform(df_output)
# Out:
# 21/12/10 10:23:59 WARN TaskSetManager: Stage 7 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.

# %%
lr = (LinearRegression(featuresCol='features', labelCol='quality', predictionCol='pred_quality', standardization=True))
linearModel = lr.fit(scaled_df)
# Out:
# 21/12/10 10:23:59 WARN Instrumentation: [3af2792c] regParam is zero, which might cause numerical instability and overfitting.
# 21/12/10 10:23:59 WARN TaskSetManager: Stage 10 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 10:24:00 WARN InstanceBuilder$NativeBLAS: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 21/12/10 10:24:00 WARN InstanceBuilder$NativeBLAS: Failed to load implementation from:dev.ludovic.netlib.blas.ForeignLinkerBLAS
# 21/12/10 10:24:00 WARN InstanceBuilder$NativeLAPACK: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK
# 21/12/10 10:24:00 WARN TaskSetManager: Stage 11 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.

# %%
scaled_df.columns
# Out:
# ['alcohol',
#  'chlorides',
#  'citric acid',
#  'density',
#  'fixed_acidity',
#  'free sulfur dioxide',
#  'pH',
#  'quality',
#  'residual sugar',
#  'sulphates',
#  'total sulfur dioxide',
#  'volatile acidity',
#  'features',
#  'features_scaled']

# %%
#train_data, test_data = scaled_df.randomSplit([.8, .2])

# %%
predictions = linearModel.transform(scaled_df)
predictions.select("pred_quality", "quality").show()
# Out:
# +------------------+-------+
# |      pred_quality|quality|
# +------------------+-------+
# | 5.290416290080088|    5.0|
# | 7.105420183050455|    6.0|
# |  6.09691215251064|    7.0|
# | 5.399626625489759|    5.0|
# | 5.072889605542571|    5.0|
# |  4.58458363257796|    5.0|
# | 6.238527589759769|    5.0|
# |6.3802143524383155|    5.0|
# | 6.634884344408249|    6.0|
# |  5.11326284572209|    6.0|
# |5.2482599082741785|    4.0|
# | 5.771741249214358|    5.0|
# | 5.493506856016836|    6.0|
# | 6.345636734530444|    5.0|
# |5.5333422652802255|    6.0|
# | 5.423304425489675|    6.0|
# | 4.278330957751791|    7.0|
# | 4.235551574586964|    5.0|
# | 6.646556983794937|    6.0|
# | 5.169984350961954|    5.0|
# +------------------+-------+
# only showing top 20 rows
# 21/12/10 10:24:00 WARN TaskSetManager: Stage 12 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.

# %%
X_test = X_test.combine_first(y_test)

# %%
X_test = spark.createDataFrame(X_test)

# %%
X_test = assembler.transform(X_test)

# %%
predictions = linearModel.transform(X_test)
predictions.select("pred_quality", "quality").show()
# Out:
# +------------------+-------+
# |      pred_quality|quality|
# +------------------+-------+
# | 4.837158182826784|    5.0|
# |  4.83759594903421|    6.0|
# | 6.135279418568189|    7.0|
# | 7.911884514788767|    8.0|
# |6.1472170158438075|    5.0|
# |1.0768872981565778|    4.0|
# | 6.058923521664667|    6.0|
# | 6.036249470177893|    5.0|
# | 5.333225867046394|    7.0|
# | 5.952383595652805|    5.0|
# | 5.340760250564074|    6.0|
# | 5.461908815039806|    7.0|
contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:14 WARN TaskSetManager: Stage 23628 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:14 WARN TaskSetManager: Stage 23629 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:14 WARN TaskSetManager: Stage 23630 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:14 WARN TaskSetManager: Stage 23631 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:14 WARN TaskSetManager: Stage 23632 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:14 WARN TaskSetManager: Stage 23633 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:14 WARN TaskSetManager: Stage 23634 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:14 WARN TaskSetManager: Stage 23635 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:14 WARN TaskSetManager: Stage 23636 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:14 WARN TaskSetManager: Stage 23637 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:14 WARN TaskSetManager: Stage 23638 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:15 WARN TaskSetManager: Stage 23639 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:15 WARN TaskSetManager: Stage 23640 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# Best model parameters {Param(parent='LinearRegression_83c6b98549f2', name='aggregationDepth', doc='suggested depth for treeAggregate (>= 2).'): 2, Param(parent='LinearRegression_83c6b98549f2', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.1, Param(parent='LinearRegression_83c6b98549f2', name='maxIter', doc='max number of iterations (>= 0).'): 2, Param(parent='LinearRegression_83c6b98549f2', name='epsilon', doc='The shape parameter to control the amount of robustness. Must be > 1.0. Only valid when loss is huber'): 1.5, Param(parent='LinearRegression_83c6b98549f2', name='regParam', doc='regularization parameter (>= 0).'): 0.6}
# +------------------+-------+
# |      pred_quality|quality|
# +------------------+-------+
# | 5.169794940936285|    5.0|
# | 5.000719954455107|    6.0|
# | 5.929909376704543|    7.0|
# | 7.285155260837669|    8.0|
# | 5.801508096350403|    5.0|
# |  2.41048193227185|    4.0|
# |   5.9474345554883|    6.0|
# | 5.834673922248399|    5.0|
# | 5.684634876097718|    7.0|
# |5.6852131708766365|    5.0|
# | 5.486766214141937|    6.0|
# | 5.257386622282667|    7.0|
# | 4.796155961002455|    5.0|
# | 5.459484080708307|    5.0|
# | 5.985204576399724|    6.0|
# | 5.361796091625294|    5.0|
# |  6.34604889414895|    6.0|
# | 5.435649623327819|    5.0|
# | 7.083205793918111|    6.0|
# |6.2692176540263205|    6.0|
# +------------------+-------+
# only showing top 20 rows
#
#  R^2 on test data for LINEAR REGRESSION_with_hyper-parameter = 0.896487

# %%
# Random Forest Regressor

rf = RandomForestRegressor(featuresCol='features', labelCol='quality', predictionCol='pred_quality')
pipeline = Pipeline(stages=[rf])

rf_model = pipeline.fit(scaled_df)

predictions = rf_model.transform(X_test)
predictions.select("pred_quality", "quality").show()

rmse = evaluator.evaluate(predictions)
print(" RMSE on test data for RANDOM FOREST REGRESSION= %g" % rmse)
# Out:
# 21/12/10 11:06:55 WARN TaskSetManager: Stage 23643 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:55 WARN TaskSetManager: Stage 23644 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:55 WARN TaskSetManager: Stage 23645 contains a task of very large size (6511 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:56 WARN TaskSetManager: Stage 23647 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:56 WARN TaskSetManager: Stage 23649 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:56 WARN TaskSetManager: Stage 23651 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:56 WARN TaskSetManager: Stage 23653 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:06:57 WARN TaskSetManager: Stage 23655 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# +------------------+-------+
# |      pred_quality|quality|
# +------------------+-------+
# | 4.429857231975658|    5.0|
# | 4.704756931744831|    6.0|
# |  6.45314167717846|    7.0|
# | 7.317587999521299|    8.0|
# |5.0627470048435725|    5.0|
# | 4.124706117883991|    4.0|
# | 6.781250904546292|    6.0|
# | 4.915555541538952|    5.0|
# | 5.691483645054998|    7.0|
# | 5.033754855118982|    5.0|
# | 5.230658870104921|    6.0|
# | 6.176869049507982|    7.0|
# | 4.372078832925473|    5.0|
# | 5.197271019465137|    5.0|
# |7.1577418849606005|    6.0|
# | 5.661930238800854|    5.0|
# | 6.889381291399258|    6.0|
# |  4.97429722307871|    5.0|
# | 7.164613089059119|    6.0|
# | 6.363281919002826|    6.0|
# +------------------+-------+
# only showing top 20 rows
#
#  RMSE on test data for RANDOM FOREST REGRESSION= 0.882006

# %%
# Hyper-parameter Tuning for Random Forest Regressor

pipeline = Pipeline(stages=[rf])

paramGrid = ParamGridBuilder().addGrid(rf.maxDepth, [5,30]).build()

cross_val = CrossValidator(estimator=pipeline,
                           estimatorParamMaps=paramGrid,
                           evaluator=RegressionEvaluator().setLabelCol("quality").setPredictionCol("pred_quality"),
                           numFolds=2)

cvModel = cross_val.fit(scaled_df)
print(cvModel.getEstimatorParamMaps()[np.argmax(cvModel.avgMetrics)])

predictions = cvModel.transform(X_test)
predictions.select("pred_quality", "quality").show()

rmse = evaluator.evaluate(predictions)
print(" RMSE on test data for RANDOM FOREST REGRESSION with hyper-parameter tuning = %g" % rmse)
# Out:
# 21/12/10 11:25:20 WARN TaskSetManager: Stage 24561 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:21 WARN TaskSetManager: Stage 24562 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:21 WARN TaskSetManager: Stage 24563 contains a task of very large size (6511 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:21 WARN TaskSetManager: Stage 24565 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:21 WARN TaskSetManager: Stage 24567 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:21 WARN TaskSetManager: Stage 24569 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:21 WARN TaskSetManager: Stage 24571 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:21 WARN TaskSetManager: Stage 24573 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:22 WARN TaskSetManager: Stage 24575 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:22 WARN TaskSetManager: Stage 24577 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:22 WARN TaskSetManager: Stage 24579 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:23 WARN DAGScheduler: Broadcasting large task binary with size 1244.5 KiB
# 21/12/10 11:25:23 WARN TaskSetManager: Stage 24581 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:23 WARN DAGScheduler: Broadcasting large task binary with size 1969.1 KiB
# 21/12/10 11:25:23 WARN TaskSetManager: Stage 24583 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:24 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 21/12/10 11:25:24 WARN TaskSetManager: Stage 24585 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:25 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 21/12/10 11:25:25 WARN TaskSetManager: Stage 24587 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:26 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 21/12/10 11:25:26 WARN TaskSetManager: Stage 24589 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:27 WARN DAGScheduler: Broadcasting large task binary with size 6.7 MiB
# 21/12/10 11:25:27 WARN TaskSetManager: Stage 24591 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:29 WARN DAGScheduler: Broadcasting large task binary with size 8.2 MiB
# 21/12/10 11:25:29 WARN TaskSetManager: Stage 24593 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:30 WARN DAGScheduler: Broadcasting large task binary with size 9.6 MiB
# 21/12/10 11:25:30 WARN TaskSetManager: Stage 24595 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:32 WARN DAGScheduler: Broadcasting large task binary with size 10.8 MiB
# 21/12/10 11:25:32 WARN TaskSetManager: Stage 24597 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25:33 WARN DAGScheduler: Broadcasting large task binary with size 11.9 MiB
# 21/12/10 11:25:33 WARN TaskSetManager: Stage 24599 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:25
contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:29 WARN DAGScheduler: Broadcasting large task binary with size 10.2 MiB
# 21/12/10 11:26:29 WARN TaskSetManager: Stage 24723 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:32 WARN DAGScheduler: Broadcasting large task binary with size 12.3 MiB
# 21/12/10 11:26:32 WARN TaskSetManager: Stage 24725 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:34 WARN DAGScheduler: Broadcasting large task binary with size 14.4 MiB
# 21/12/10 11:26:34 WARN TaskSetManager: Stage 24727 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:36 WARN DAGScheduler: Broadcasting large task binary with size 16.2 MiB
# 21/12/10 11:26:36 WARN TaskSetManager: Stage 24729 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:39 WARN DAGScheduler: Broadcasting large task binary with size 17.8 MiB
# 21/12/10 11:26:39 WARN TaskSetManager: Stage 24731 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:41 WARN DAGScheduler: Broadcasting large task binary with size 19.1 MiB
# 21/12/10 11:26:41 WARN TaskSetManager: Stage 24733 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:44 WARN DAGScheduler: Broadcasting large task binary with size 20.1 MiB
# 21/12/10 11:26:44 WARN TaskSetManager: Stage 24735 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:46 WARN DAGScheduler: Broadcasting large task binary with size 20.8 MiB
# 21/12/10 11:26:46 WARN TaskSetManager: Stage 24737 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:49 WARN DAGScheduler: Broadcasting large task binary with size 21.3 MiB
# 21/12/10 11:26:49 WARN TaskSetManager: Stage 24739 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:51 WARN DAGScheduler: Broadcasting large task binary with size 21.7 MiB
# 21/12/10 11:26:51 WARN TaskSetManager: Stage 24741 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:54 WARN DAGScheduler: Broadcasting large task binary with size 21.9 MiB
# 21/12/10 11:26:54 WARN TaskSetManager: Stage 24743 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:56 WARN DAGScheduler: Broadcasting large task binary with size 22.0 MiB
# 21/12/10 11:26:56 WARN TaskSetManager: Stage 24745 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:26:59 WARN DAGScheduler: Broadcasting large task binary with size 22.1 MiB
# 21/12/10 11:26:59 WARN TaskSetManager: Stage 24747 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:27:01 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 21/12/10 11:27:01 WARN TaskSetManager: Stage 24749 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:27:03 WARN DAGScheduler: Broadcasting large task binary with size 17.8 MiB
# 21/12/10 11:27:04 WARN TaskSetManager: Stage 24751 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/10 11:27:05 WARN DAGScheduler: Broadcasting large task binary with size 15.6 MiB
# 21/12/10 11:27:05 WARN TaskSetManager: Stage 24753 contains a task of very large size (6510 KiB). The maximum recommended task size is 1000 KiB.
# {Param(parent='RandomForestRegressor_5e78954ba92d', name='maxDepth', doc='Maximum depth of the tree. (>= 0) E.g., depth 0 means 1 leaf node; depth 1 means 1 internal node + 2 leaf nodes. Must be in range [0, 30].'): 30}
# +------------+-------+
# |pred_quality|quality|
# +------------+-------+
# |        5.05|    5.0|
# |        5.85|    6.0|
# |        6.05|    7.0|
# |        6.85|    8.0|
# |        5.75|    5.0|
# |        5.05|    4.0|
# |         6.0|    6.0|
# |         6.2|    5.0|
# |        5.55|    7.0|
# |        5.45|    5.0|
# |         5.9|    6.0|
# |         7.0|    7.0|
# |         5.0|    5.0|
# |        5.55|    5.0|
# |        6.95|    6.0|
# |        6.05|    5.0|
# |        6.05|    6.0|
# |         5.0|    5.0|
# |        6.95|    6.0|
# |         6.3|    6.0|
# +------------+-------+
# only showing top 20 rows
#
#  RMSE on test data for RANDOM FOREST REGRESSION = 0.686309
